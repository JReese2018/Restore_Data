# %% [markdown]
# Use Cases:
# 1. Compare how many members you had in one month vs another (i.e March 2022 vs March 2023)
# 2. Get a list of all members that were members in both months
# 3. Get a list of who was a member in the past but no longer a member now

# %% [markdown]
# 1. Load previous month datasets
# 2. Load current months datasets
# 3. Locate where names are the same
# 4. Spit out the names that are on previous month but not on current month
# 5. Tell me how many of which membership is they were on in the previous month

# %%
## Load Pandas
import pandas as pd

# %%
## Import datasets
previous_df = pd.read_csv('march2023.csv')
current_df = pd.read_csv('january2024.csv')
current_df
# Out:
#     Studio Code Purchase Date  Invoice ID  Client ID   First Name  \
# 0         FL005      1/1/2024    31700346     211522    Christine
# 1         FL005      1/1/2024    31700347     599282      Deborah
# 2         FL005      1/1/2024    31700348     669466         Vane
# 3         FL005      1/1/2024    31700349     706036        Paula
# 4         FL005      1/1/2024    31700350     714362         Joel
# ..          ...           ...         ...        ...          ...
# 337       FL005     1/31/2024    31904047     617498       Rafael
# 338       FL005     1/31/2024    31904048     781589  Mariangelli
# 339       FL005     1/31/2024    31904049   30596936       Bionny
# 340       FL005     1/31/2024    31904050     957039          Liz
# 341       FL005     1/31/2024    31904051   30635377       Sophia
#
#           Last Name                            Email       Phone #  \
# 0          Norwitch            cswitch@bellsouth.net  3.053237e+09
# 1             Marks               synergy928@aol.com  7.868533e+09
# 2                 V                    mv4@gmail.com  7.862710e+09
# 3            Samper      paulasamper040612@gmail.com  7.204437e+09
# 4          Castillo                  cjoel777@me.com  3.057937e+09
# ..              ...                              ...           ...
# 337            Arte              rarte26@outlook.com  7.865893e+09
# 338         Alvarez          mariangelli25@gmail.com  7.863545e+09
# 339           Ayala              bionnyayala@aol.com  3.052995e+09
# 340       Sanderson  elizabeth.h.sanderson@gmail.com  6.462078e+09
# 341  Rodriguez Ruso               srruso26@gmail.com  3.054317e+09
#
#     Therapy Category Business Category                 Item  Sales Rep  \
# 0        Memberships        Membership      Core Membership        NaN
# 1        Memberships        Membership  Level Up Membership        NaN
# 2        Memberships        Membership  Discover Membership        NaN
# 3        Memberships        Membership  Discover Membership        NaN
# 4        Memberships        Membership  Discover Membership        NaN
# ..               ...               ...                  ...        ...
# 337      Memberships        Membership  Discover Membership        NaN
# 338      Memberships        Membership  Level Up Membership        NaN
# 339      Memberships        Membership  Discover Membership        NaN
# 340      Memberships        Membership  Level Up Membership        NaN
# 341      Memberships        Membership  Level Up Membership        NaN
#
#     Autopay Status  Tax Amount  Amount  Discount  Gross adjusted Revenue  \
# 0          Success           0     NaN       0.0                   279.0
# 1          Success           0     NaN       0.0                   199.0
# 2          Success           0     NaN       0.0                   119.0
# 3          Success           0     NaN       0.0                   107.1
# 4          Success           0     NaN       0.0                   119.0
# ..             ...         ...     ...       ...                     ...
# 337        Success           0     NaN       0.0                   119.0
# 338        Success           0     NaN       0.0                   179.1
# 339        Success           0     NaN       0.0                   119.0
# 340        Success           0     NaN       0.0                   199.0
# 341        Success           0     NaN       0.0                   199.0
#
#      Quantity  Credit Used
# 0           1            0
# 1           1            0
# 2           1            0
# 3           1            0
# 4           1            0
# ..        ...          ...
# 337         1            0
# 338         1            0
# 339         1            0
# 340         1            0
# 341         1            0
#
# [342 rows x 19 columns]

# %%
## Clean data
previous_df = previous_df.drop(columns=['Studio Code', 'Invoice ID', 'Client ID', 'Therapy Category', 'Business Category', 'Sales Rep', 'Autopay Status', 'Tax Amount', 'Amount', 'Discount', 'Gross adjusted Revenue', 'Quantity', 'Credit Used'])
current_df = current_df.drop(columns=['Studio Code', 'Invoice ID', 'Client ID', 'Therapy Category', 'Business Category', 'Sales Rep', 'Autopay Status', 'Tax Amount', 'Amount', 'Discount', 'Gross adjusted Revenue', 'Quantity', 'Credit Used'])
previous_df
# Out:
#     Purchase Date First Name   Last Name                    Email  \
# 0        3/1/2023      Diana     Izeddin       gizeddin@yahoo.com
# 1        3/1/2023     Marsha  Goolcharan    actormarsha@gmail.com
# 2        3/1/2023     Marcos      Molina      Mmolina25@yahoo.com
# 3        3/1/2023     Amanda     Fuentes   my.amanda917@gmail.com
# 4        3/1/2023      Brean    Beckford       breanromeo@aol.com
# ..            ...        ...         ...                      ...
# 449     3/31/2023    Heather     Metoyer      hmmetoyer@gmail.com
# 450     3/31/2023    Yunitza    Gonzalez       gyunitza@yahoo.com
# 451     3/31/2023    Melissa      Cancio  canciomelissa@yahoo.com
# 452     3/31/2023     Rafael        Arte      rarte26@outlook.com
# 453     3/31/2023    Anthony       Hevia          golasso@aol.com
#
#          Phone #                 Item
# 0     7863908851  Wellness Membership
# 1     3239831445  Discover Membership
# 2     7863031151   Restore Membership
# 3     3053056025   Restore Membership
# 4     3057104492   Restore Membership
# ..           ...                  ...
# 449   8138925252  Discover Membership
# 450  17863188973  Discover Membership
# 451   7864575107  Discover Membership
# 452   7865893488  Discover Membership
# 453   3057942794  Discover Membership
#
# [454 rows x 6 columns]

# %%
## Combine Names
current_df['Name'] = current_df['First Name'] + ' ' + current_df['Last Name']
current_df = current_df.drop(columns=['First Name', 'Last Name'])
current_df = current_df[['Name', 'Email', 'Phone #', 'Item', 'Purchase Date']]

previous_df['Name'] = previous_df['First Name'] + ' ' + previous_df['Last Name']
previous_df = previous_df.drop(columns=['First Name', 'Last Name'])
previous_df = previous_df[['Name', 'Email', 'Phone #', 'Item', 'Purchase Date']]

## Printing
previous_df
# Out:
#                   Name                    Email      Phone #  \
# 0        Diana Izeddin       gizeddin@yahoo.com   7863908851
# 1    Marsha Goolcharan    actormarsha@gmail.com   3239831445
# 2        Marcos Molina      Mmolina25@yahoo.com   7863031151
# 3       Amanda Fuentes   my.amanda917@gmail.com   3053056025
# 4       Brean Beckford       breanromeo@aol.com   3057104492
# ..                 ...                      ...          ...
# 449    Heather Metoyer      hmmetoyer@gmail.com   8138925252
# 450   Yunitza Gonzalez       gyunitza@yahoo.com  17863188973
# 451     Melissa Cancio  canciomelissa@yahoo.com   7864575107
# 452        Rafael Arte      rarte26@outlook.com   7865893488
# 453      Anthony Hevia          golasso@aol.com   3057942794
#
#                     Item Purchase Date
# 0    Wellness Membership      3/1/2023
# 1    Discover Membership      3/1/2023
# 2     Restore Membership      3/1/2023
# 3     Restore Membership      3/1/2023
# 4     Restore Membership      3/1/2023
# ..                   ...           ...
# 449  Discover Membership     3/31/2023
# 450  Discover Membership     3/31/2023
# 451  Discover Membership     3/31/2023
# 452  Discover Membership     3/31/2023
# 453  Discover Membership     3/31/2023
#
# [454 rows x 5 columns]

# %%
## Identify the ammount of members of each category in previous dataset
previous_discover_count = len(previous_df.loc[previous_df['Item'] == 'Discover Membership'])
previous_levelup_count = len(previous_df.loc[previous_df['Item'] == 'Level Up Membership'])
previous_elevate_count = len(previous_df.loc[previous_df['Item'] == 'Elevate Membership'])
previous_core_count = len(previous_df.loc[previous_df['Item'] == 'Core Membership'])
previous_restore_count = len(previous_df.loc[previous_df['Item'] == 'Restore Membership'])
previous_restorecouples_count = len(previous_df.loc[previous_df['Item'] == 'Restore Membership - Couples'])
previous_wellness_count = len(previous_df.loc[previous_df['Item'] == 'Wellness Membership'])
previous_wellnesscouples_count = len(previous_df.loc[previous_df['Item'] == 'Wellness Membership - Couples'])
previous_daily_count = len(previous_df.loc[previous_df['Item'] == 'Daily Membership'])

previous_membership_count = len(previous_df)

print(f'Number of Discover Memberships: {previous_discover_count}')
print(f'Number of Level Up Memberships: {previous_levelup_count}')
print(f'Number of Elevate Memberships: {previous_elevate_count}')
print(f'Number of Core Memberships: {previous_core_count}')
print(f'Number of Restore Memberships: {previous_restore_count}')
print(f'Number of Restore Couples Memberships: {previous_restorecouples_count}')
print(f'Number of Wellness Memberships: {previous_wellness_count}')
print(f'Number of Wellness Couples Memberships: {previous_wellnesscouples_count}')
print(f'Number of Daily Memberships: {previous_daily_count}')

print(f'Total number of all memberships: {previous_membership_count}')
# Out:
# Number of Discover Memberships: 240
# Number of Level Up Memberships: 84
# Number of Elevate Memberships: 0
# Number of Core Memberships: 23
# Number of Restore Memberships: 55
# Number of Restore Couples Memberships: 19
# Number of Wellness Memberships: 17
# Number of Wellness Couples Memberships: 6
# Number of Daily Memberships: 10
# Total number of all memberships: 454

# %%
month = previous_df['Purchase Date'].head(1).str.split('/').str[0].values[0]
if month == '1':
    month = 'January'
elif month == '2':
    month = 'February'
elif month == '3':
    month = 'March'
elif month == '4':
    month = 'April'
elif month == '5':
    month = 'May'
elif month == '6':
    month = 'June'
elif month == '7':
    month = 'July'
elif month == '8':
    month = 'August'
elif month == '9':
    month = 'September'
elif month == '10':
    month = 'October'
elif month == '11':
    month = 'November'
elif month == '12':
    month = 'December'

month
# Out:
# 'March'

# %%
## Identify the ammount of members of each category in current dataset
current_discover_count = len(current_df.loc[current_df['Item'] == 'Discover Membership'])
current_levelup_count = len(current_df.loc[current_df['Item'] == 'Level Up Membership'])
current_elevate_count = len(current_df.loc[current_df['Item'] == 'Elevate Membership'])
current_core_count = len(current_df.loc[current_df['Item'] == 'Core Membership'])
current_restore_count = len(current_df.loc[current_df['Item'] == 'Restore Membership'])
current_restorecouples_count = len(current_df.loc[current_df['Item'] == 'Restore Membership - Couples'])
current_wellness_count = len(current_df.loc[current_df['Item'] == 'Wellness Membership'])
current_wellnesscouples_count = len(current_df.loc[current_df['Item'] == 'Wellness Membership - Couples'])
current_daily_count = len(current_df.loc[current_df['Item'] == 'Daily Membership'])

current_membership_count = len(current_df)

print(f'Number of Discover Memberships: {current_discover_count}')
print(f'Number of Level Up Memberships: {current_levelup_count}')
print(f'Number of Elevate Memberships: {current_elevate_count}')
print(f'Number of Core Memberships: {current_core_count}')
print(f'Number of Restore Memberships: {current_restore_count}')
print(f'Number of Restore Couples Memberships: {current_restorecouples_count}')
print(f'Number of Wellness Memberships: {current_wellness_count}')
print(f'Number of Wellness Couples Memberships: {current_wellnesscouples_count}')
print(f'Number of Daily Memberships: {current_daily_count}')

print(f'Total number of all memberships: {current_membership_count}')
# Out:
# Number of Discover Memberships: 173
# Number of Level Up Memberships: 103
# Number of Elevate Memberships: 11
# Number of Core Memberships: 12
# Number of Restore Memberships: 22
# Number of Restore Couples Memberships: 4
# Number of Wellness Memberships: 4
# Number of Wellness Couples Memberships: 1
# Number of Daily Memberships: 3
# Total number of all memberships: 342

# %%
merged_df = pd.merge(previous_df, current_df, on='Name', suffixes=('_prev', '_current'), how='outer', indicator=True)

# Filter out rows that are only in the previous dataframe
lost_members = merged_df[merged_df['_merge'] == 'left_only'][['Name', 'Email_prev', 'Phone #_prev', 'Item_prev']].values.tolist()

print(lost_members)
# Out:
# [['Diana Izeddin', 'gizeddin@yahoo.com', 7863908851.0, 'Wellness Membership'], ['Marsha Goolcharan', 'actormarsha@gmail.com', 3239831445.0, 'Discover Membership'], ['Brean Beckford', 'breanromeo@aol.com', 3057104492.0, 'Restore Membership'], ['Shannon Mathew', 'nonnahskm93@gmail.com', 5864532770.0, 'Core Membership'], ['Kelcie Laroche', 'klaroche13@gmail.com', 5183370829.0, 'Level Up Membership'], ['Paula Sanchez', 'psanchezderio@gmail.com', 7864522950.0, 'Level Up Membership'], ['Gaby Sota', 'mgsz18@hotmail.com', 3058154896.0, 'Discover Membership'], ['Helmut Gaensel', 'hgaensel@gmail.com', 7862900511.0, 'Restore Membership'], ['Julio Affon', 'affonvaljulito@gmail.com', 7868684935.0, 'Discover Membership'], ['Manav Sharma', 'manav007@gmail.com', 9177830180.0, 'Restore Membership - Couples'], ['Christian Cruz', 'cc98kt03@rocketmail.com', 7864862850.0, 'Discover Membership'], ['Marcello Cello Nicoletti', 'Marcellonicoletti@gmail.com', 17865563195.0, 'Level Up Membership'], ['Valentina Salas', 'valentina.salas@gmail.com', 7863515456.0, 'Discover Membership'], ['James Parker', 'jay@jtpcompanies.com', 4044278111.0, 'Level Up Membership'], ['Harry Froget', 'hfroget@gmail.com', 7865536583.0, 'Level Up Membership'], ['Jose Esteves', 'jaesteves01@gmail.com', 7863489211.0, 'Level Up Membership'], ['Katie Abbott', 'katielabbott@comcast.net', 6465417339.0, 'Discover Membership'], ['Courtney Chason', 'courtneychason32@yahoo.com', 3058985417.0, 'Discover Membership'], ['Karine Verela', 'karineverela@gmail.com', 7868329562.0, 'Discover Membership'], ['Allison Bowen', 'allisonbowen83@gmail.com', 3054505412.0, 'Discover Membership'], ['James Lupino', 'jlupino4@gmail.com', 3053934555.0, 'Discover Membership'], ['Bianca Vonbank', 'bianca.vonbank@asu.edu', 4807359655.0, 'Restore Membership'], ['Jessica Rummel', 'jessicarummel@hotmail.com', 3054585484.0, 'Discover Membership'], ['Andres Rodriguez', 'laxroz@aol.com', 3054949773.0, 'Discover Membership'], ['Valentina Amadeo', 'sandraamadeo@hotmail.com', 3057243731.0, 'Core Membership'], ['Pedro Quintero', 'peteyq09@gmail.com', 7866069610.0, 'Level Up Membership'], ['Zubeida Alawi', 'alawiz@me.com', 17037311418.0, 'Discover Membership'], ['Steve Pandolfe', 'Stevep4747@gmail.com', 8084917351.0, 'Discover Membership'], ['Jaime Rodriguez', 'Jrod8904@icloud.com', 3053224440.0, 'Discover Membership'], ['Brian Tarr', 'acer72780@gmail.com', 5616340925.0, 'Discover Membership'], ['Francheska Lara', 'filara428@yahoo.com', 17863598189.0, 'Discover Membership'], ['Joyce Chavarria', 'jri1220@yahoo.com', 3059628573.0, 'Discover Membership'], ['Luiz Carlos Couto', 'lcfcouto@gmail.com', 7865255807.0, 'Restore Membership'], ['Alessandro Azor', 'alexazor104@yahoo.com', 9047751815.0, 'Discover Membership'], ['Stanley Kowlessar', 'skowlessar@thrusttech.com', 3054903457.0, 'Discover Membership'], ['Suzanne Levitats', 'smtats@aol.com', 3052818043.0, 'Restore Membership'], ['Libertad Vega-Pulles', 'naomip@acepropertyservices.com', 3058016139.0, 'Level Up Membership'], ['Christopher Ezell', 'chrisezell@gmail.com', 2513007206.0, 'Discover Membership'], ['Erika N Ernie Sierra', 'esierra29@comcast.net', 17864433374.0, 'Discover Membership'], ['Amanda Schmidt', 'Schmidt.dphie17@gmail.com', 7867124995.0, 'Daily Membership'], ['George Savage', 'gss@savagelaw.net', 3054913182.0, 'Restore Membership - Couples'], ['Alfredo Espinosa', 'alfredocu2015@gmail.com', 9173254375.0, 'Restore Membership - Couples'], ['Myriam Kowlessar', 'myriam@thrusttech.com', 7862535223.0, 'Discover Membership'], ['Monica Granados', 'monica_granados@hotmail.com', 3059343471.0, 'Restore Membership - Couples'], ['Amy Morrow', 'amyannmorrow@gmail.com', 9139153414.0, 'Discover Membership'], ['Custodio Toledo', 'custodio@mytoledo.net', 3055885659.0, 'Daily Membership'], ['Sergio Jaramillo', 'splurge4@hotmail.com', 3054956800.0, 'Discover Membership'], ['Kennedy Martinez', 'kennedymartinez01@gmail.com', 7862140977.0, 'Level Up Membership'], ['Priscila Rodriguez ...

# %%
## Grab Names on previous df and put them in a list
overlap_members = []

for index, row1 in previous_df.iterrows():
    for index, row2 in current_df.iterrows():
        name1 = row1['Name']
        name2 = row2['Name']
        if name1 != name2:
            continue
        else:
            my_list = [row1['Name'], row1['Email'], row1['Phone #'], row1['Item']]
            overlap_members.append(my_list)
            continue
    continue

overlap_members
# Out:
# [['Marcos Molina', 'Mmolina25@yahoo.com', 7863031151, 'Restore Membership'],
#  ['Amanda Fuentes',
#   'my.amanda917@gmail.com',
#   3053056025,
#   'Restore Membership'],
#  ['Christian Leiva', 'crl07c@gmail.com', 3059796192, 'Discover Membership'],
#  ['Deborah Marks', 'synergy928@aol.com', 7868532700, 'Level Up Membership'],
#  ['Fernando Cosme',
#   'djflipmiami@gmail.com',
#   7864441717,
#   'Discover Membership'],
#  ['Jose Zeron', 'zeronmetal@hotmail.com', 7862514419, 'Daily Membership'],
#  ['Thomas Pratt',
#   'prattthomas69@gmail.com',
#   3056081967,
#   'Discover Membership'],
#  ['Ethel Rodas Rodas',
#   'erodas@aeendoscopy.com',
#   3053026227,
#   'Discover Membership'],
#  ['Ariel Rodriguez',
#   'arodelighting@gmail.com',
#   3052441803,
#   'Restore Membership'],
#  ['Andre Rojas',
#   'rojassevilla01@hotmail.com',
#   17863952289,
#   'Level Up Membership'],
#  ['Tiffany Moe', 'tiramesu71@yahoo.com', 3057100096, 'Discover Membership'],
#  ['Makeba Kelly', 'mkelly6870@gmail.com', 9545523985, 'Discover Membership'],
#  ['Madison Lupino',
#   'maddie.lupino@gmail.com',
#   3056198141,
#   'Discover Membership'],
#  ['Audra Kurland', 'akcreates22@gmail.com', 3058155255, 'Core Membership'],
#  ['Christine Norwitch',
#   'cswitch@bellsouth.net',
#   3053237243,
#   'Core Membership'],
#  ['Armando Bardisa',
#   'armandobardisa@me.com',
#   3052815406,
#   'Restore Membership - Couples'],
#  ['Jacqueline James',
#   'lyttlebosslady@gmail.com',
#   3055196754,
#   'Restore Membership'],
#  ['Jessica White',
#   'jessicamwhite@gmail.com',
#   7862002729,
#   'Level Up Membership'],
#  ['Natalia Gutzalenko', 'nanibatt@gmail.com', 3052187472, 'Core Membership'],
#  ['Noemi Garcia', 'ngandrade72@gmail.com', 9545594597, 'Discover Membership'],
#  ['Manny Ramirez',
#   'manny.ramirez@e-ssentialnetworks.com',
#   3059651626,
#   'Discover Membership'],
#  ['Electra Spillis',
#   'electra6@bellsouth.net',
#   3057251700,
#   'Wellness Membership'],
#  ['Diego Ballina', 'cancunbaby63@yahoo.com', 3059175676, 'Restore Membership'],
#  ['Jennifer Bracci', 'jjufbh@aol.com', 3057530087, 'Restore Membership'],
#  ['Leslie Abascal',
#   'leslie.abascal@gmail.com',
#   3059844255,
#   'Discover Membership'],
#  ['Iris Suarez', 'irisysuarez@gmail.com', 3053455577, 'Level Up Membership'],
#  ['Giovanna Aviles',
#   'giovanna.aviles@gmail.com',
#   7863500519,
#   'Discover Membership'],
#  ['Magda Konczak', 'lusinskama@gmail.com', 7866172962, 'Discover Membership'],
#  ['Peter Konczak', 'p.konczak@gmail.com', 7867791580, 'Discover Membership'],
#  ['Freddy Mosqueda',
#   'freddymosquedap@gmail.com',
#   7864871852,
#   'Discover Membership'],
#  ['Alina Nicole', 'alina.yaniz@gmail.com', 3055622154, 'Level Up Membership'],
#  ['Jaqui Leiro', 'ajleiro@hotmail.com', 7863442884, 'Discover Membership'],
#  ['Lucas Argudin',
#   'alexcargudin@gmail.com',
#   3059899675,
#   'Discover Membership'],
#  ['Jose Antonio Perez',
#   'jap@agaveholdingsllc.com',
#   3053319383,
#   'Discover Membership'],
#  ['Andres Franco',
#   'andresfrancop@comcast.net',
#   7865461000,
#   'Restore Membership - Couples'],
#  ['Jose Alvarez',
#   'jalvarez@proroofingsales.com',
#   3052195379,
#   'Restore Membership'],
#  ['Chad Thorson', 'cthorson@med.miami.edu', 3059037153, 'Discover Membership'],
#  ['Shereena Chang', 'Changst@hotmail.com', 3059153913, 'Restore Membership'],
#  ['Tatiana Puche',
#   'tpuche@perezabellolaw.com',
#   3057665136,
#   'Wellness Membership'],
#  ['Luigi Gonzalez', 'luigi@voipjr.com', 7864865770, 'Discover Membership'],
#  ['Julie Dill', 'juliedill29@gmail.com', 3054585110, 'Level Up Membership'],
#  ['Jason Leibowitz',
#   'jason.m.leibowitz@gmail.com',
#   6096385223,
#   'Level Up Membership'],
#  ['Dacil Espinosa',
#   'dacilespinosa@gmail.com',
#   7862094695,
#   'Level Up Membership'],
#  ['Cheryl Komanduri',
#   'ckomanduri@gmail.com',
#   8326462708,
#   'Wellness Membership'],
#  ['Martha Seoane', 'fastsurvey@aol.com', 3052982706, 'Wellness Membership'],
#  ['Mayra Oliva', 'readysetgo67@yahoo.com', 7862801140, 'Discover Membership'],
#  ['Terry Marks',
#   'terry.robert.marks@gmail.com',
#   3219488400,
#   'Core Membership'],
#  ['Eduardo Monteagudo',
#   'edmonte@bellsouth.net',
#   3052167775,
#   'Discover Membership'],
#  ['Tania Prado', 'tjprado@yahoo.com', 3057107742, 'Discover Membership'],
#  ['Sonia Guerra', 'sonia@jd-miami.com', 7864443975, 'Discover Membership'],
#  ['Adriana Luzardo',
#   'nani.luzardo@gmail.com',
#   3059246545,
#   'Level Up Membership'],
#  ['Freddy Neyra',
#   'freddyneyra11@gmail.com',
#   7865318082,
#   'Level Up Membership'],
#  ['Henry Irizarry',
#   'Hirizarry@hotmail.com',
#   3375170955,
#   'Level Up Membership'],
#  ['Donna Kass', 'thekasses@aol.com', 3052985993, 'Discover Membership'],
#  ['Noemi Garcia', 'ngandrade72@gmail.com', 9545594597, 'Discover Membership'],
#  ['Elliot Wittlin', 'ewittlin@gmail.com', 5853053954, 'Discover Membership'],
#  ['Marco Alfaro', 'marco.alfaro@live.com', 7862862597, 'Core Membership'],
#  ['Joey Pfaeffli', 'jpfaeffli@gmail.com', 3054954474, 'Level Up Membership'],
#  ['Michael Pujol', 'mpujol@msn.com', 3059727649, 'Level Up Membership'],
#  ['Vernon Quinn', 'quinn3350@gmail.com', 3055254170, 'Restore Membership'],
#  ['Ernesto Frye', 'ernestofrye@gmail.com', 7865540754, 'Restore Membership'],
#  ['Noel Leon Jr', 'Nleons@yahoo.com', 3057909081, 'Discover Membership'],
#  ['Brendon Brewster',
#   'brendon@webvanguard.com',
#   2157407883,
#   'Level Up Membership'],
#  ['Patrick Goddard',
#   'Pwrgoddard@gmail.com',
#   7863252040,
#   'Discover Membership'],
#  ['Ignacio Duquesne',
#   'ignacio.duquesne@gmail.com',
#   7863013456,
#   'Level Up Membership'],
#  ['Alfredo Richards',
#   'alfredoflash@icloud.com',
#   3053210732,
#   'Discover Membership'],
#  ['Ivan Malavé-Vidal',
#   'xrgym@bellsouth.net',
#   3057208134,
#   'Discover Membership'],
#  ['Rosie Suarez', 'msuarez1016@aol.com', 3059897909, 'Restore Membership'],
#  ['Lilliam Corrales',
#   'lilucorrales@hotmail.com',
#   7862618501,
#   'Discover Membership'],
#  ['Linda Mcmillan',
#   'ljmcmillan1212@gmail.com',
#   9104949512,
#   'Discover Membership'],
#  ['Brianna Alvarez',
#   'Bri.alvarez0922@gmail.com',
#   3057462103,
#   'Discover Membership'],
#  ['Kaley Eddington',
#   'keddington910@aol.com',
#   7272351000,
#   'Discover Membership'],
#  ['Joseph Garcia', 'jsgarcia05@msn.com', 3053229624, 'Core Membership'],
#  ['Lauren Flores',
#   'lauren.flores27@gmail.com',
#   3053328684,
#   'Discover Membership'],
#  ['Christina Ng', 'ctng212@gmail.com', 13055826671, 'Discover Membership'],
#  ['Jeffrey Young', 'jyoung3416@gmail.com', 7862957080, 'Discover Membership'],
#  ['David Adler', 'dadler@adlergroup.com', 3055629241, 'Discover Membership'],
#  ['Adam Batchelor',
#   'adamleebatchelor@gmail.com',
#   7868775923,
#   'Discover Membership'],
#  ['Steven George', 'ssteven98@yahoo.com', 7322108500, 'Discover Membership'],
#  ['Maria Callejas',
#   'martha.callejas06@gmail.com',
#   3056324689,
#   'Discover Membership'],
#  ['Amy Hicks', 'amywhicks@hotmail.com', 3057246110, 'Restore Membership'],
#  ['Shica Marckioli',
#   'marckiolishica@yahoo.com',
#   3058788819,
#   'Restore Membership'],
#  ['Adriana Albornoz',
#   'adrianatalbornoz@hotmail.com',
#   3053330371,
#   'Level Up Membership'],
#  ['Evin O Driscoll',
#   'evin.odriscoll1@gmail.com',
#   7816403562,
#   'Level Up Membership'],
#  ['Charles Alfonso', 'charliealf@att.net', 8059072653, 'Level Up Membership'],
#  ['Juan Anillo', 'janillo1943@gmail.com', 7864738195, 'Discover Membership'],
#  ['Jennifer Vitrella',
#   'jenvitrella@gmail.com',
#   3059752453,
#   'Discover Membership'],
#  ['Tristan Hernandez',
#   'tahernandez@live.com',
#   7862615009,
#   'Discover Membership'],
#  ['Andrea Volpe Naves',
#   'andivolpe@hotmail.com',
#   7867748155,
#   'Core Membership'],
#  ['Javier Rodriguez', 'javy@lucaelite.com', 3058077096, 'Discover Membership'],
#  ['Jeffrey Jones', 'jeffreypjones@me.com', 2818061016, 'Wellness Membership'],
#  ['Andrew Castellanos',
#   'castellanosimg@gmail.com',
#   3053187225,
#   'Discover Membership'],
#  ['Scott Hazard', 'shazard@gmail.com', 9258990494, 'Level Up Membership'],
#  ['Francisco Ferre',
#   'ferrefrancisco@yahoo.com',
#   7865972378,
#   'Discover Membership'],
#  ['Desmond Allen',
#   'Desmond.allen24@yahoo.com',
#   3053233988,
#   'Discover Membership'],
#  ['Ivan Herrera',
#   'tmfonlinemedia@gmail.com',
#   7869204628,
#   'Discover Membership'],
#  ['Ammer Cabrera',
#   'ammer.cabrera@gmail.com',
#   3056084464,
#   'Level Up Membership'],
#  ['Paula Fay', 'wakefamily305@gmail.com', 3052059002, 'Level Up Membership'],
#  ['Ray Hernandez',
#   'rayclrecovery86@gmail.com',
#   3059019108,
#   'Restore Membership'],
#  ['Alberto De Solo', 'ardesolo@gmail.com', 7862466880, 'Discover Membership'],
#  ['Sara Lowrey', 'sflowrey12@gmail.com', 3059043182, 'Core Membership'],
#  ['Rafael Barraza',
#   'rafaelbarraza28@hotmail.com',
#   7867257535,
#   'Restore Membership - Couples'],
#  ['Patricia Mendoza',
#   'patricia@oceansale.com',
#   3055467670,
#   'Discover Membership'],
#  ['Dariusz Kosiorek',
#   'dakosiorek@gmail.com',
#   3059840314,
#   'Level Up Membership'],
#  ['Rolando Lacayo',
#   'rolandodlacayo@gmail.com',
#   3057319065,
#   'Level Up Membership'],
#  ['Jorge Sevilla',
#   'Jorge.sevilla19@yahoo.com',
#   7865978302,
#   'Restore Membership'],
#  ['Peter Gross', 'petergross357@aol.com', 3052981226, 'Restore Membership'],
#  ['Abigail Bert',
#   'shimmiehayshee@gmail.com',
#   9548044286,
#   'Discover Membership'],
#  ['Donna Cohen', 'donna@donnacohenms.com', 3057857752, 'Restore Membership'],
#  ['Erika Cappiello',
#   'erikarachel74@gmail.com',
#   3054408487,
#   'Daily Membership'],
#  ['Frank Dages', 'dagesfrank@yahoo.com', 3058158898, 'Level Up Membership'],
#  ['Edison Cruz',
#   'edisoncruz@smalltimemovers.net',
#   7862345452,
#   'Daily Membership'],
#  ['Eduardo Del Rosal',
#   'edelrosal@icloud.com',
#   7865270989,
#   'Discover Membership'],
#  ['David Farrell',
#   'davidferrell123@gmail.com',
#   4042136035,
#   'Discover Membership'],
#  ['Lelia Harrington',
#   'harringtonlelia@gmail.com',
#   5162363159,
#   'Discover Membership'],
#  ['Henry Irizarry',
#   'Hirizarry@hotmail.com',
#   3375170955,
#   'Level Up Membership'],
#  ['Henry Irizarry',
#   'Hirizarry@hotmail.com',
#   3375170955,
#   'Level Up Membership'],
#  ['Susan Stevens', 'flatcreek47@yahoo.com', 4233603104, 'Discover Membership'],
#  ['Bianca Hoshina', 'bmd1209@gmail.com', 2038035849, 'Discover Membership'],
#  ['David Walsh',
#   'davidedwardwalsh@gmail.com',
#   8476443433,
#   'Level Up Membership'],
#  ['John Marshall',
#   'mars7199@bellsouth.net',
#   3057909194,
#   'Discover Membership'],
#  ['Paula Samper',
#   'paulasamper040612@gmail.com',
#   7204437341,
#   'Discover Membership'],
#  ['Ashley Movshovich', 'ashkmov@gmail.com', 2032161167, 'Discover Membership'],
#  ['Enrique Arriola',
#   'eaac2112@hotmail.com',
#   7866088644,
#   'Level Up Membership'],
#  ['Marilu Perez-Perez',
#   'mariluperez-perez@hotmail.com',
#   3055287304,
#   'Level Up Membership'],
#  ['Stephanie Krenyitzky',
#   'stephaniekrenyitzky@gmail.com',
#   3053388178,
#   'Discover Membership'],
#  ['Juan Montes De Oca',
#   'juan.montesdeoca@yahoo.com',
#   7869720610,
#   'Discover Membership'],
#  ['Mercy Cabrera',
#   'mercy.cabrera@outlook.com',
#   3055257050,
#   'Wellness Membership'],
#  ['Kenny Sharkey',
#   'ken@verticalreality.com',
#   3052194000,
#   'Level Up Membership'],
#  ['Claudette Casal',
#   'claudettecasal@att.net',
#   3056063685,
#   'Discover Membership'],
#  ['Maria Lopez',
#   'mariacrepemaker@gmail.com',
#   13057265203,
#   'Discover Membership'],
#  ['Vane V', 'mv4@gmail.com', 7862710243, 'Discover Membership'],
#  ['Masson Liang', 'hello@massonliang.com', 3055707075, 'Restore Membership'],
#  ['Ronald Chirinos', 'ronaldsurf@yahoo.com', 7864208590, 'Restore Membership'],
#  ['Ashley Brenninkmeijer',
#   'ashleybrenninkmeijer@gmail.com',
#   3053378818,
#   'Level Up Membership'],
#  ['Claudia Herrera', 'claustro05@mac.com', 3057647296, 'Discover Membership'],
#  ['Virginia Silverio Silverio',
#   'nvsday64@gmail.com',
#   7866915947,
#   'Level Up Membership'],
#  ['Jennifer Perez',
#   'perezalamodds@gmail.com',
#   6142033273,
#   'Discover Membership'],
#  ['Nicole Rapanos',
#   'nikkirapanos@gmail.com',
#   7865863205,
#   'Discover Membership'],
#  ['Marc Anderson', 'marcander@icloud.com', 9084163153, 'Discover Membership'],
#  ['Robert Barthelmess',
#   'rmbarthelmess@gmail.com',
#   3057765328,
#   'Core Membership'],
#  ['Gianpaul Sanchez Lagomarcino',
#   'iann.slb@hotmail.com',
#   17866919957,
#   'Discover Membership'],
#  ['Arianne Siasso', 'arisasso@hotmail.com', 3059265908, 'Discover Membership'],
#  ['Claudia Fernandez',
#   'clpintof@aol.com',
#   3057331769,
#   'Restore Membership - Couples'],
#  ['Eytan Mcmanus', 'mcastanera@yahoo.com', 3057538725, 'Restore Membership'],
#  ['Julian Leslie',
#   'julianleslie05@gmail.com',
#   3055425257,
#   'Restore Membership'],
#  ['Susana Crespo', 'suzycrespo@gmail.com', 7862175552, 'Restore Membership'],
#  ['Lina Perez - Abreu',
#   'linaperezabreu@diversifiedmia.com',
#   3054507014,
#   'Discover Membership'],
#  ['Jose Carreras Perez',
#   'josecp33@gmail.com',
#   7542074382,
#   'Level Up Membership'],
#  ['Ljubenka Taneva',
#   'tanevaljubenka@yahoo.com',
#   3057907390,
#   'Discover Membership'],
#  ['Humberto Gil',
#   'humbertogil64@hotmail.com',
#   7868993347,
#   'Discover Membership'],
#  ['Cristina Chavarria',
#   'cchavarria1224@gmail.com',
#   3053038233,
#   'Discover Membership'],
#  ['Valleen Aguilar',
#   'valaguilar114@gmail.com',
#   7867978788,
#   'Level Up Membership'],
#  ['Teresa Seda',
#   'teresa.seda@walgreens.com',
#   7876616297,
#   'Discover Membership'],
#  ['Carole Valle', 'sed1028@yahoo.com', 3058153949, 'Core Membership'],
#  ['Nancy Patterson',
#   'npatterson86@gmail.com',
#   3059706945,
#   'Level Up Membership'],
#  ['Maria Browning',
#   'Mfvfernandez@yahoo.com',
#   7863711740,
#   'Restore Membership'],
#  ['Elizabeth Ana', 'elyacosta@aol.com', 7864173718, 'Discover Membership'],
#  ['Jennifer Acosta',
#   'jennie2903@gmail.com',
#   3054097240,
#   'Level Up Membership'],
#  ['Mario Finamore',
#   'mariosergiofimamore@me.com',
#   7866815056,
#   'Wellness Membership - Couples'],
#  ['Lissette Aguila',
#   'lissette30@hotmail.com',
#   7862952181,
#   'Level Up Membership'],
#  ['Alexander De La Cruz',
#   'alexander.delacruz33@gmail.com',
#   7863423637,
#   'Discover Membership'],
#  ['Alexander De La Cruz',
#   'alexander.delacruz33@gmail.com',
#   7863423637,
#   'Level Up Membership'],
#  ['Monika Tefel',
#   'monika.tefel@floridamoves.com',
#   7865020010,
#   'Discover Membership'],
#  ['Joseph Wood',
#   'martiniwood77@gmail.com',
#   13052160357,
#   'Level Up Membership'],
#  ['Joel Castillo', 'cjoel777@me.com', 3057937470, 'Discover Membership'],
#  ['Cesar Guerrero', 'cesarguerrero@me.com', 3053366900, 'Discover Membership'],
#  ['Lesley Suarez', 'misie515@gmail.com', 7864437770, 'Discover Membership'],
#  ['Marisel Rodriguez',
#   'mmarrero024@gmail.com',
#   3056073182,
#   'Discover Membership'],
#  ['Lourdes Boyer', 'boyer1707@msn.com', 3052185700, 'Restore Membership'],
#  ['Luis Mazza', 'luis_mazza00@hotmail.com', 7866413848, 'Restore Membership'],
#  ['Christina Xiques', 'cxgravier@aol.com', 3052990750, 'Discover Membership'],
#  ['Vanessa Colmenarez',
#   'vanessa_cfr@hotmail.com',
#   7864796840,
#   'Discover Membership'],
#  ['Carlos Hernandez',
#   'carlos@championssc.com',
#   7862618536,
#   'Discover Membership'],
#  ['Samantha White',
#   'samantha.l.white@gmail.com',
#   3059267704,
#   'Discover Membership'],
#  ['Andrew Carricarte',
#   'alc@tritansoft.com',
#   3053215035,
#   'Discover Membership'],
#  ['Megan Hamann', 'megan.hamann@yahoo.com', 8594217809, 'Restore Membership'],
#  ['John Okunski', 'jokunski@gmail.com', 3057105106, 'Level Up Membership'],
#  ['Michael Dazzo', 'Daz1201@aol.com', 7865128331, 'Restore Membership'],
#  ['Melissa Cancio',
#   'canciomelissa@yahoo.com',
#   7864575107,
#   'Discover Membership'],
#  ['Rafael Arte', 'rarte26@outlook.com', 7865893488, 'Discover Membership'],
#  ['Anthony Hevia', 'golasso@aol.com', 3057942794, 'Discover Membership']]

# %%
## Creating dataframes
lost_members_df = pd.DataFrame(lost_members, columns=['Name', 'Email', 'Phone #', 'Membership'])
overlap_members_df = pd.DataFrame(overlap_members, columns=['Name', 'Email', 'Phone #', 'Membership'])
overlap_members_df
# Out:
#                 Name                    Email     Phone #           Membership
# 0      Marcos Molina      Mmolina25@yahoo.com  7863031151   Restore Membership
# 1     Amanda Fuentes   my.amanda917@gmail.com  3053056025   Restore Membership
# 2    Christian Leiva         crl07c@gmail.com  3059796192  Discover Membership
# 3      Deborah Marks       synergy928@aol.com  7868532700  Level Up Membership
# 4     Fernando Cosme    djflipmiami@gmail.com  7864441717  Discover Membership
# ..               ...                      ...         ...                  ...
# 177     John Okunski       jokunski@gmail.com  3057105106  Level Up Membership
# 178    Michael Dazzo          Daz1201@aol.com  7865128331   Restore Membership
# 179   Melissa Cancio  canciomelissa@yahoo.com  7864575107  Discover Membership
# 180      Rafael Arte      rarte26@outlook.com  7865893488  Discover Membership
# 181    Anthony Hevia          golasso@aol.com  3057942794  Discover Membership
#
# [182 rows x 4 columns]

# %%
lost_members_df
# Out:
#                   Name                      Email       Phone #  \
# 0        Diana Izeddin         gizeddin@yahoo.com  7.863909e+09
# 1    Marsha Goolcharan      actormarsha@gmail.com  3.239831e+09
# 2       Brean Beckford         breanromeo@aol.com  3.057104e+09
# 3       Shannon Mathew      nonnahskm93@gmail.com  5.864533e+09
# 4       Kelcie Laroche       klaroche13@gmail.com  5.183371e+09
# ..                 ...                        ...           ...
# 267    Vaushaun Harvin       bopsbabygirl@aol.com  7.863667e+09
# 268     Donovan Manuel  donovanmanuel27@gmail.com  1.770742e+10
# 269  Cristina Sullivan    cristinasullivan@me.com  7.862295e+09
# 270    Heather Metoyer        hmmetoyer@gmail.com  8.138925e+09
# 271   Yunitza Gonzalez         gyunitza@yahoo.com  1.786319e+10
#
#               Membership
# 0    Wellness Membership
# 1    Discover Membership
# 2     Restore Membership
# 3        Core Membership
# 4    Level Up Membership
# ..                   ...
# 267  Discover Membership
# 268  Level Up Membership
# 269  Level Up Membership
# 270  Discover Membership
# 271  Discover Membership
#
# [272 rows x 4 columns]
