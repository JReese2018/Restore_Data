# 14          Cryoskin Facial | 5 Pack                  3  12/20/2023

# %%
## Now we can get rid of columns that we don't need and redefine the variable
df_skin = df_skin.drop(columns=['Studio Name', 'Day of Issue Date', 'Day of Expire Date', 'Client ID', 'Email', 'Max date'])

## Printing
df_skin.head(10)
# Out:
#                 Full Name     Phone #                Credit Description  \
# 0          Chloe - Markey  7864502530  Circadia Oxygen Facial | 10 Pack
# 1       Erika - Cappiello  3054408487  Circadia Oxygen Facial | 10 Pack
# 2       Erika - Cappiello  3054408487  Circadia Oxygen Facial | 10 Pack
# 3          Ashley - Rosen  6463301606   Circadia Oxygen Facial | 3 Pack
# 4         Kenny - Sharkey  3052194000   Circadia Oxygen Facial | 5 Pack
# 5   Valeria - Arias-Ferro  3052058890   Circadia Oxygen Facial | 5 Pack
# 6   Valeria - Arias-Ferro  3052058890   Circadia Oxygen Facial | 5 Pack
# 7          Ashley - Rosen  6463301606     Circadia Oxygen Facial Credit
# 8  Maria Claudia - Savage  7862806222     Circadia Oxygen Facial Credit
# 9         Susan - Stevens  4233603104     Circadia Oxygen Facial Credit
#
#    Remaining Credits
# 0                  9
# 1                  1
# 2                  9
# 3                  3
# 4                  5
# 5                  1
# 6                  3
# 7                  1
# 8                  1
# 9                  1

# %%
## We'll also rename the columns to make them easily usable and redefine the varible
df_skin = df_skin.rename(columns={'Full Name': 'full_name'})
df_skin = df_skin.rename(columns={'Phone #': 'phone'})
df_skin = df_skin.rename(columns={'Credit Description': 'credit_description'})
df_skin = df_skin.rename(columns={'Remaining Credits': 'remaining_credits'})

## Printing
df_skin.head(10)
# Out:
#                 full_name       phone                credit_description  \
# 0          Chloe - Markey  7864502530  Circadia Oxygen Facial | 10 Pack
# 1       Erika - Cappiello  3054408487  Circadia Oxygen Facial | 10 Pack
# 2       Erika - Cappiello  3054408487  Circadia Oxygen Facial | 10 Pack
# 3          Ashley - Rosen  6463301606   Circadia Oxygen Facial | 3 Pack
# 4         Kenny - Sharkey  3052194000   Circadia Oxygen Facial | 5 Pack
# 5   Valeria - Arias-Ferro  3052058890   Circadia Oxygen Facial | 5 Pack
# 6   Valeria - Arias-Ferro  3052058890   Circadia Oxygen Facial | 5 Pack
# 7          Ashley - Rosen  6463301606     Circadia Oxygen Facial Credit
# 8  Maria Claudia - Savage  7862806222     Circadia Oxygen Facial Credit
# 9         Susan - Stevens  4233603104     Circadia Oxygen Facial Credit
#
#    remaining_credits
# 0                  9
# 1                  1
# 2                  9
# 3                  3
# 4                  5
# 5                  1
# 6                  3
# 7                  1
# 8                  1
# 9                  1

# %%
## There are going to be some decrepencies with this because some of the data from the 'Remainind Credits' column might not have numbers
## Because of that, I'm going to go ahead and get rid of them as they will mess up the calculations
df_skin = df_skin.dropna()

## Printing
df_skin.head(10)
# Out:
#                 full_name       phone                credit_description  \
# 0          Chloe - Markey  7864502530  Circadia Oxygen Facial | 10 Pack
# 1       Erika - Cappiello  3054408487  Circadia Oxygen Facial | 10 Pack
# 2       Erika - Cappiello  3054408487  Circadia Oxygen Facial | 10 Pack
# 3          Ashley - Rosen  6463301606   Circadia Oxygen Facial | 3 Pack
# 4         Kenny - Sharkey  3052194000   Circadia Oxygen Facial | 5 Pack
# 5   Valeria - Arias-Ferro  3052058890   Circadia Oxygen Facial | 5 Pack
# 6   Valeria - Arias-Ferro  3052058890   Circadia Oxygen Facial | 5 Pack
# 10          Lois - Bonwit  3052814569          Cryoskin Facial | 3 Pack
# 11          Teresa - Seda  7876616297          Cryoskin Facial | 3 Pack
# 12      Andres - Silveira  7862532884          Cryoskin Facial | 5 Pack
#
#     remaining_credits initial_credits
# 0                   9              10
# 1                   1              10
# 2                   9              10
# 3                   3               3
# 4                   5               5
# 5                   1               5
# 6                   3               5
# 10                  2               3
# 11                  1               3
# 12                  1               5

# %% [markdown]
# <font size="5">Working with bad data</font>

# %%
## We need to get the initial credits in an integer in order to perform calculations
## Since we are wokring with data that does not give us the init
df_skin['initial_credits'] = df_skin['credit_description'].astype(str).str.extract(r'(\d+)', expand=False)

## Printing
df_skin.head(10)
# Out:
#                 full_name       phone                credit_description  \
# 0          Chloe - Markey  7864502530  Circadia Oxygen Facial | 10 Pack
# 1       Erika - Cappiello  3054408487  Circadia Oxygen Facial | 10 Pack
# 2       Erika - Cappiello  3054408487  Circadia Oxygen Facial | 10 Pack
# 3          Ashley - Rosen  6463301606   Circadia Oxygen Facial | 3 Pack
# 4         Kenny - Sharkey  3052194000   Circadia Oxygen Facial | 5 Pack
# 5   Valeria - Arias-Ferro  3052058890   Circadia Oxygen Facial | 5 Pack
# 6   Valeria - Arias-Ferro  3052058890   Circadia Oxygen Facial | 5 Pack
# 10          Lois - Bonwit  3052814569          Cryoskin Facial | 3 Pack
# 11          Teresa - Seda  7876616297          Cryoskin Facial | 3 Pack
# 12      Andres - Silveira  7862532884          Cryoskin Facial | 5 Pack
#
#     remaining_credits initial_credits
# 0                   9              10
# 1                   1              10
# 2                   9              10
# 3                   3               3
# 4                   5               5
# 5                   1               5
# 6                   3               5
# 10                  2               3
# 11                  1               3
# 12                  1               5

# %%
## If we tried to iterrate through the rows and do our calculations, it wont work
## Let's see why it won't
df_skin.dtypes
# Out:
# full_name             object
# phone                  int64
# credit_description    object
# remaining_credits      int64
# initial_credits       object
# dtype: object

# %%
## As you can see, the new initial credits is seen as an object
## We can change this by turning it into a string type and then an integer
df_skin['initial_credits'] = df_skin['initial_credits'].astype(str).astype(int)

## Now let's check
df_skin.dtypes
# Out:
# full_name             object
# phone                  int64
# credit_description    object
# remaining_credits      int64
# initial_credits        int32
# dtype: object

# %%
## Let start performing calculations
skin_list = []

for index, row in df_skin.iterrows():
    remaining = row['remaining_credits']
    initial = row['initial_credits']
    calculated_percentage = (remaining / initial) * 100
    utilization = 100 - calculated_percentage
    if utilization > 60:
        my_list = [row.full_name, row.phone, row.credit_description, row.remaining_credits]
        skin_list.append(my_list)

## Printing
skin_list
# Out:
# [['Erika - Cappiello', 3054408487, 'Circadia Oxygen Facial | 10 Pack', 1],
#  ['Valeria - Arias-Ferro', 3052058890, 'Circadia Oxygen Facial | 5 Pack', 1],
#  ['Teresa - Seda', 7876616297, 'Cryoskin Facial | 3 Pack', 1],
#  ['Andres - Silveira', 7862532884, 'Cryoskin Facial | 5 Pack', 1],
#  ['Sherie Huffman - Swerdlow',
#   3052138934,
#   'Hydrafacial | Platinum | 3 Pack',
#   1],
#  ['Ashley - Rosen', 6463301606, 'Hydrafacial | Premium | 3 Pack', 1],
#  ['Charlotte - De Paula', 3058019051, 'Hydrafacial | Signature | 5 Pack', 1]]

# %% [markdown]
# ## Making the List actionable

# %%
## Now that we have the list, let's turn it into a dataframe
core_list_df = pd.DataFrame(skin_list, columns=['Full Name', 'Phone Number', 'Credit Description', 'Remaining Credits'])

## Printing
core_list_df
# Out:
#                    Full Name  Phone Number                Credit Description  \
# 0          Erika - Cappiello    3054408487  Circadia Oxygen Facial | 10 Pack
# 1      Valeria - Arias-Ferro    3052058890   Circadia Oxygen Facial | 5 Pack
# 2              Teresa - Seda    7876616297          Cryoskin Facial | 3 Pack
# 3          Andres - Silveira    7862532884          Cryoskin Facial | 5 Pack
# 4  Sherie Huffman - Swerdlow    3052138934   Hydrafacial | Platinum | 3 Pack
# 5             Ashley - Rosen    6463301606    Hydrafacial | Premium | 3 Pack
# 6       Charlotte - De Paula    3058019051  Hydrafacial | Signature | 5 Pack
#
#    Remaining Credits
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# 5                  1
# 6                  1

# %%
## Since that looks good, we can turn that into an excel sheet and send it to the reps
core_list_df.to_excel('Remaining Skin Credits.xlsx')
